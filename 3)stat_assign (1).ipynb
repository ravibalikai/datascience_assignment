# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('sales_data_with_discounts.csv')
data.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
df= data._get_numeric_data()

# %%
df.head()
# Out:
#    Volume  Avg Price  Total Sales Value   Discount  Discount Amount  \
# 0      15      12100             181500  11.654820     21153.498820
# 1      10      10100             101000  11.560498     11676.102961
# 2       7      16100             112700   9.456886     10657.910157
# 3       6      20100             120600   6.935385      8364.074702
# 4       3       8100              24300  17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
df.rename(columns={'Discount Rate (%)':'Discount'}, inplace = True)

# %%
mn=df[['Volume','Avg Price','Total Sales Value','Discount','Discount Amount','Net Sales Value']].mean()
mn
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount                15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
md=df[['Volume','Avg Price','Total Sales Value','Discount','Discount Amount','Net Sales Value']].median()
md
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount               16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
mo=df[['Volume','Avg Price','Total Sales Value','Discount','Discount Amount','Net Sales Value']].mode()
mo
# Out:
#      Volume  Avg Price  Total Sales Value   Discount  Discount Amount  \
# 0       3.0      400.0            24300.0   5.007822        69.177942
# 1       NaN      450.0                NaN   5.055218        73.025199
# 2       NaN      500.0                NaN   5.059801        93.649161
# 3       NaN     1300.0                NaN   5.072124        94.682735
# 4       NaN     8100.0                NaN   5.084108       102.705757
# ..      ...        ...                ...        ...              ...
# 445     NaN        NaN                NaN  19.940610     17900.983733
# 446     NaN        NaN                NaN  19.965340     21153.498820
# 447     NaN        NaN                NaN  19.976879     21496.675367
# 448     NaN        NaN                NaN  19.982257     25328.224204
# 449     NaN        NaN                NaN  19.992407     25738.022194
#
#      Net Sales Value
# 0         326.974801
# 1         330.822058
# 2         466.350839
# 3         485.317265
# ...

# %%
df[['Volume','Avg Price','Total Sales Value','Discount','Discount Amount','Net Sales Value']].describe()
# Out:
#            Volume     Avg Price  Total Sales Value    Discount  \
# count  450.000000    450.000000         450.000000  450.000000
# mean     5.066667  10453.433333       33812.835556   15.155242
# std      4.231602  18079.904840       50535.074173    4.220602
# min      1.000000    290.000000         400.000000    5.007822
# 25%      3.000000    465.000000        2700.000000   13.965063
# 50%      4.000000   1450.000000        5700.000000   16.577766
# 75%      6.000000  10100.000000       53200.000000   18.114718
# max     31.000000  60100.000000      196400.000000   19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# max       25738.022194    179507.479049

# %%
sns.histplot(df['Volume'],kde=True) #'Avg Price','Total Sales Value','Discount','Discount Amount','Net Sales Value']])
# Out:
# <Axes: xlabel='Volume', ylabel='Count'>

# %%
## the gra[h is right skeweed.

# %%
sns.histplot(df['Avg Price'],kde=True)
# Out:
# <Axes: xlabel='Avg Price', ylabel='Count'>

# %%
sns.histplot(df['Total Sales Value'],kde=True)
# Out:
# <Axes: xlabel='Total Sales Value', ylabel='Count'>

# %%
sns.histplot(df['Discount'],kde=True)
# Out:
# <Axes: xlabel='Discount', ylabel='Count'>

# %%
sns.histplot(df['Discount Amount'],kde=True)
# Out:
# <Axes: xlabel='Discount Amount', ylabel='Count'>

# %%
sns.histplot(df['Net Sales Value'],kde=True)
# Out:
# <Axes: xlabel='Net Sales Value', ylabel='Count'>

# %%
sns.boxplot(df['Volume'])
# Out:
# <Axes: ylabel='Volume'>

# %%
df.head()
# Out:
#    Volume  Avg Price  Total Sales Value   Discount  Discount Amount  \
# 0      15      12100             181500  11.654820     21153.498820
# 1      10      10100             101000  11.560498     11676.102961
# 2       7      16100             112700   9.456886     10657.910157
# 3       6      20100             120600   6.935385      8364.074702
# 4       3       8100              24300  17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
sns.boxplot(df['Avg Price'])
# Out:
# <Axes: ylabel='Avg Price'>

# %%
sns.boxplot(df['Total Sales Value'])
# Out:
# <Axes: ylabel='Total Sales Value'>

# %%
sns.boxplot(df['Discount'])
# Out:
# <Axes: ylabel='Discount'>

# %%
sns.boxplot(df['Discount Amount'])
# Out:
# <Axes: ylabel='Discount Amount'>

# %%
sns.boxplot(df['Net Sales Value'])
# Out:
# <Axes: ylabel='Net Sales Value'>

# %%
data.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
sns.countplot(data=data, x='City')
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
sns.countplot(data=data, y='Brand')
# Out:
# <Axes: xlabel='count', ylabel='Brand'>

# %%
sns.countplot(data=data, y='Model')
# Out:
# <Axes: xlabel='count', ylabel='Model'>
