# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("glass.xlsx", sheet_name="glass")

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.shape
# Out:
# (214, 10)

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %% [markdown]
# # 2) Data Visualization

# %%
df_numeric = df._get_numeric_data()

# %%
df_numeric
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df_numeric.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
col=['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type']
for i in col:
    plt.figure(figsize=(6,4))
    sns.histplot(df[i],kde=True)

# %%
col=['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type']
for i in col:
    plt.figure(figsize=(6,4))
    sns.boxplot(x= df[i])

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
df.drop_duplicates()
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [213 rows x 10 columns]

# %%
df.shape
# Out:
# (214, 10)

# %% [markdown]
# # 3 ) Data Preprocessing

# %% [markdown]
# ### there is no need to delete or impute the data because there are no null values.

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
df_numeric.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
col = ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type']

for i in col:
    print(f"\n--- Value Counts for {i} ---")
    print(df[i].value_counts())
# Out:
# --- Value Counts for RI ---
# RI
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51754    2
# 1.51841    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: count, Length: 178, dtype: int64
#
# --- Value Counts for Na ---
# Na
# 13.02    5
# 13.21    5
# 13.00    5
# 13.64    4
# 13.33    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: count, Length: 142, dtype: int64
#
# --- Value Counts for Mg ---
# Mg
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 2.76     1
# 3.15     1
# 2.90     1
# 3.83     1
# 1.78     1
# Name: count, Length: 94, dtype: int64
#
# --- Value Counts for Al ---
# Al
# 1.54    8
# 1.19    6
# 1.43    5
# 1.29    5
# 1.23    5
#        ..
# 1.08    1
# 1.64    1
# 1.61    1
# 1.07    1
# 1.94    1
# Name: count, Length: 118, dtype: int64
#
# --- Value Counts for Si ---
# Si
# 72.86    4
# 72.99    4
# 73.10    4
# 73.28    4
# 73.11    4
# ...

# %% [markdown]
# ### the data has all the numeric values so need of encoding, as well as no need of scaling

# %% [markdown]
# # 4) model Deployment

# %%
from  sklearn.ensemble import RandomForestClassifier

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
x=df.drop('Type',axis = 1)

# %%
y=df['Type']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = RandomForestClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[11  0  0  0  0  0]
#  [ 5  9  0  0  0  0]
#  [ 3  0  0  0  0  0]
#  [ 0  3  0  1  0  0]
#  [ 0  0  0  0  3  0]
#  [ 0  0  0  0  0  8]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.73      1.00      0.85        11
#            2       0.85      0.79      0.81        14
#            3       1.00      0.67      0.80         3
#            5       1.00      0.50      0.67         4
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         8
#
#     accuracy                           0.86        43
#    macro avg       0.93      0.83      0.85        43
# weighted avg       0.88      0.86      0.86        43

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'max_depth': [3, 4, 5, 6, 8],          # How deep the tree goes
    'min_samples_split': [2, 5, 10],        # Min samples to split a node
    'min_samples_leaf': [1, 2, 4],          # Min samples at a leaf node
    'criterion': ['gini', 'entropy']        # Which impurity measure
}

# %%
# Create the base model
model = RandomForestClassifier(random_state=42)


grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=5,                    # 5-fold cross validation
    scoring='accuracy',      # What metric to optimize
    n_jobs=-1,               # Use all CPU cores (faster)
    verbose=1                # Shows progress bar
)

# Fit it on your TRAINING data (X_train, y_train)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 8],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy', verbose=1)

# %%
# Print the best hyperparameters found
print("Best Parameters:", grid_search.best_params_)

# Print the average CV accuracy (across the 5 folds)
print("Best Cross-Validation Accuracy:", grid_search.best_score_)

# Get the final model trained with these best params
best_model = grid_search.best_estimator_
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Best Cross-Validation Accuracy: 0.7492436974789916

# %% [markdown]
# # 5) bagginng and boosting

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
bag1 = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=6)
bag1.fit(x_train, y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=6)

# %%
y_pred = bag1.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.73      1.00      0.85        11
#            2       0.91      0.71      0.80        14
#            3       0.50      0.33      0.40         3
#            5       1.00      0.75      0.86         4
#            6       1.00      0.67      0.80         3
#            7       0.80      1.00      0.89         8
#
#     accuracy                           0.81        43
#    macro avg       0.82      0.74      0.77        43
# weighted avg       0.83      0.81      0.81        43

# %%
from  sklearn.ensemble import AdaBoostClassifier

# %%
bag2 = AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=6)
bag2.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=6)

# %%
y_pred1 = bag2.predict(x_test)

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.67      0.91      0.77        11
#            2       0.86      0.43      0.57        14
#            3       0.75      1.00      0.86         3
#            5       1.00      1.00      1.00         4
#            6       1.00      0.67      0.80         3
#            7       0.73      1.00      0.84         8
#
#     accuracy                           0.77        43
#    macro avg       0.83      0.83      0.81        43
# weighted avg       0.80      0.77      0.75        43

# %% [markdown]
# # in boosting the the accuracy is 77 % in bagging it is 81%

# %% [markdown]
# ### in bagging we use many trees simultaneoulsy to get the output where as in boosting we train the model based on the error of the earlier model

# %% [markdown]
# ### we can use classweight='balance'
